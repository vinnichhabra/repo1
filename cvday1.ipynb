# %% [markdown]
# <a href="https://colab.research.google.com/github/vinnichhabra/repo1/blob/master/cvday1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!usr/bin/python3
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import cv2

# %%
#checking version
print(cv2.__version__)
# Out:
# 3.4.3

# %%
img=cv2.imread('urv.jpg')

# %%
img
# Out:
# array([[[243, 242, 246],
#         [240, 239, 243],
#         [231, 230, 234],
#         ...,
#         [215, 213, 213],
#         [218, 216, 216],
#         [183, 181, 181]],
#
#        [[252, 251, 255],
#         [225, 224, 228],
#         [236, 235, 239],
#         ...,
#         [216, 214, 214],
#         [218, 216, 216],
#         [184, 182, 182]],
#
#        [[253, 252, 255],
#         [244, 243, 247],
#         [222, 221, 225],
#         ...,
#         [217, 215, 215],
#         [220, 218, 218],
#         [185, 183, 183]],
#
#        ...,
#
#        [[ 98,  94, 100],
#         [104, 102, 108],
#         [190, 187, 196],
#         ...,
#         [201, 199, 199],
#         [212, 210, 210],
#         [185, 185, 185]],
#
#        [[144, 140, 146],
#         [ 80,  78,  84],
#         [145, 142, 151],
#         ...,
#         [201, 199, 199],
#         [212, 210, 210],
#         [185, 185, 185]],
#
#        [[142, 138, 144],
#         [149, 147, 153],
#         [ 92,  89,  98],
# ...

# %%
# print shape

img.shape
# Out:
# (168, 299, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
#to display
plt.imshow(img)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=299x168 at 0x7EFD5BD78908>

# %%
myimg=np.zeros((512,512))
img=cv2.imread('urv.jpg',1)
# 1 means image in same colour channel --GRB or RGB
# 0 means no colour channel --black & white --gray image

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=299x168 at 0x7EFD4F493C50>

# %%
img1=cv2.imread('urv.jpg',-1)

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=299x168 at 0x7EFD4F493780>

# %%
x,y,z=cv2.split(img) #splitting into bgr

# %%
cv2_imshow(x)
# Out:
# <PIL.Image.Image image mode=L size=299x168 at 0x7EFD4F493CC0>

# %%
cv2.line(img,(0,0),(150,160),(0,0,255),3)
# Out:
# array([[[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [215, 213, 213],
#         [218, 216, 216],
#         [183, 181, 181]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [216, 214, 214],
#         [218, 216, 216],
#         [184, 182, 182]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [217, 215, 215],
#         [220, 218, 218],
#         [185, 183, 183]],
#
#        ...,
#
#        [[ 98,  94, 100],
#         [104, 102, 108],
#         [190, 187, 196],
#         ...,
#         [201, 199, 199],
#         [212, 210, 210],
#         [185, 185, 185]],
#
#        [[144, 140, 146],
#         [ 80,  78,  84],
#         [145, 142, 151],
#         ...,
#         [201, 199, 199],
#         [212, 210, 210],
#         [185, 185, 185]],
#
#        [[142, 138, 144],
#         [149, 147, 153],
#         [ 92,  89,  98],
# ...

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=299x168 at 0x7EFD4F4A8588>

# %%
cv2.rectangle(img,(50,50),(100,150),(0,250,0),3)
# Out:
# array([[[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [215, 213, 213],
#         [218, 216, 216],
#         [183, 181, 181]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [216, 214, 214],
#         [218, 216, 216],
#         [184, 182, 182]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [217, 215, 215],
#         [220, 218, 218],
#         [185, 183, 183]],
#
#        ...,
#
#        [[ 98,  94, 100],
#         [104, 102, 108],
#         [190, 187, 196],
#         ...,
#         [201, 199, 199],
#         [212, 210, 210],
#         [185, 185, 185]],
#
#        [[144, 140, 146],
#         [ 80,  78,  84],
#         [145, 142, 151],
#         ...,
#         [201, 199, 199],
#         [212, 210, 210],
#         [185, 185, 185]],
#
#        [[142, 138, 144],
#         [149, 147, 153],
#         [ 92,  89,  98],
# ...

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=299x168 at 0x7EFD4F42F080>
